# %% [markdown]
# #Assignment 03

# %%
import pandas as pd

# %%
df = pd.read_csv("Students_Performance.csv")

# %% [markdown]
# Male and Female participants in the test

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
gender_cnt = df['gender'].value_counts()

# %%
gender_cnt
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# Students Parental level of education

# %%
parental_level = df['parental level of education'].value_counts()

# %%
parental_level
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# Who scores the most on average for math, reading and
# writing based on

# %% [markdown]
# *i*. Gender ii. Test preparation course

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
average = df.groupby(['gender','test preparation course'])[['math score','reading score','writing score']].mean()

# %%
average
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 67.108696      77.375000      78.793478
#        none                      61.320359      69.955090      68.982036
# male   completed                 72.988506      70.793103      70.339080
#        none                      66.467532      62.581169      59.551948

# %% [markdown]
# scoring variation for
# math, reading and writing based on
# i. Gender
# ii. Test preparation course

# %%
variance = df.groupby(['gender','test preparation course'])[['math score','reading score','writing score']].var()

# %%
variance
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                208.173913     161.175546     149.836897
#        none                     272.602767     214.241220     225.495172
# male   completed                197.098133     185.297987     166.098233
#        none                     205.513600     184.843553     181.394687

# %%
std_deviation = df.groupby(['gender','test preparation course']).std()[['math score','reading score','writing score']]
# Out:
# <ipython-input-18-72e3e1d6bb27>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   std_deviation = df.groupby(['gender','test preparation course']).std()[['math score','reading score','writing score']]

# %%
std_deviation
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 14.428233      12.695493      12.240788
#        none                      16.510686      14.636981      15.016497
# male   completed                 14.039164      13.612420      12.887910
#        none                      14.335746      13.595718      13.468284

# %% [markdown]
# to give bonus points
# to the top 25% of students based on their math score

# %%
import numpy as np

# %%
math_scr = df['math score']

# %%
cutoff_scr = np.percentile(math_scr,75)

# %%
top25_percnt = df[df['math score'] >= cutoff_scr]

# %%
bonus_point = 5
top25_percnt['bonus_point'] = bonus_point
top25_percnt.to_csv('students_with_bonus.csv',index=False)
# Out:
# <ipython-input-29-a437019bfd37>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top25_percnt['bonus_point'] = bonus_point

# %%
df1 = pd.read_csv("students_with_bonus.csv")

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group A                 high school  free/reduced
# 1    female        group B             master's degree  free/reduced
# 2    female        group B           bachelor's degree  free/reduced
# 3    female        group B             master's degree      standard
# 4    female        group B                 high school      standard
# ..      ...            ...                         ...           ...
# 250    male        group E                some college      standard
# 251    male        group A                some college      standard
# 252    male        group D                some college      standard
# 253    male        group E          associate's degree  free/reduced
# 254    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...
